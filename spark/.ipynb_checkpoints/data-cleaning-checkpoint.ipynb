# %% [markdown]
# ## firebase setup

# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore
import os

SERVICE_ACCOUNT_KEY_PATH = os.environ.get("FIREBASE_SERVICE_ACCOUNT_KEY_PATH", "./cstam2-1f2ec-firebase-adminsdk-fbsvc-2ab61a7ed6.json")

try:
    # Check if the default app is already initialized
    app = firebase_admin.get_app()
    print("Firebase Admin SDK already initialized. Reusing existing app instance.")
except ValueError:
    # If not initialized, proceed with initialization
    try:
        cred = credentials.Certificate(SERVICE_ACCOUNT_KEY_PATH)
        app = firebase_admin.initialize_app(cred)
        print("Firebase Admin SDK initialized successfully.")
    except Exception as e:
        print(f"Error during Firebase Admin SDK initialization: {e}")
        # It's crucial to handle this error, as your app can't write to Firestore without it.
        raise # Re-raise to stop the script if Firebase initialization fails

db = firestore.client(app=app)
# Out:
# Firebase Admin SDK already initialized. Reusing existing app instance.

# %% [markdown]
# ## setup spark

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, when, lit, to_timestamp, from_unixtime
from pyspark.sql.types import StructType, StructField, StringType, TimestampType, IntegerType, DoubleType
import time
import logging
# ---------- CONFIG ----------
KAFKA_BOOTSTRAP = "kafka:29092"                  

CHECKPOINT_BASE = "/data/checkpoints"

# Configure logger
logger = logging.getLogger("DataCleaning")
logger.setLevel(logging.INFO)
handler = logging.StreamHandler()
formatter = logging.Formatter("[%(asctime)s] %(levelname)s - %(message)s")
handler.setFormatter(formatter)
if not logger.hasHandlers():
    logger.addHandler(handler)
# ---------- Spark session ----------
spark = (
    SparkSession.builder
    .appName("health-streams-to-firebase")
    .getOrCreate()
)
spark.sparkContext.setLogLevel("ERROR")

# ---------- utils ----------
def read_topic(topic, schema):
    return (
        spark.readStream
             .format("kafka")
             .option("kafka.bootstrap.servers", KAFKA_BOOTSTRAP)
             .option("subscribe", topic)
             .option("startingOffsets", "latest")
             .load()
             .selectExpr("CAST(value AS STRING) as json_str")
             .select(from_json(col("json_str"), schema).alias("data"))   # <<< fixed
             .select("data.*")
    )


heart_rate_schema = StructType([
    StructField("user_id", StringType(), True),
    StructField("time", TimestampType(), True),
    StructField("heart_rate", IntegerType(), True)
])
steps_schema = StructType([
    StructField("user_id", StringType(), True),
    StructField("time", TimestampType(), True),
    StructField("steps", IntegerType(), True)
])
calories_schema = StructType([
    StructField("user_id", StringType(), True),
    StructField("time", TimestampType(), True),
    StructField("calories", DoubleType(), True)
])
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/06 09:36:54 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ## cleaning functions

# %%
from pyspark.sql.functions import from_json, col
from pyspark.sql.functions import current_timestamp

## ---------- timestamp normalization & cleaning ----------
def normalize_timestamp(df):
    candidates = [c for c in ["timestamp", "ts", "ts_ms", "time", "created_at"] if c in df.columns]
    logger.info(f"Normalizing timestamp — candidates: {candidates}")

    if not candidates:
        logger.warning("No timestamp found — creating current-time column.")
        return df.withColumn("timestamp", current_timestamp())

    src = candidates[0]
    logger.info(f"Using '{src}' as timestamp source.")
    src_col = col(src)

    # Only convert numeric timestamps; keep native timestamps unchanged
    df = df.withColumn(
        "timestamp",
        when(src_col.cast(DoubleType()).isNotNull(), 
             to_timestamp(from_unixtime(
                 (src_col.cast(DoubleType()) / when(src_col.cast(DoubleType()) > 1e12, lit(1000.0)).otherwise(lit(1.0))).cast("long")
             ))
        ).otherwise(src_col.cast(TimestampType()))
    )

    return df.drop(src)
def clean_heart_rate(df):
    logger.info("Cleaning heart rate stream...")
    df = df.withColumn("heart_rate", col("heart_rate").cast(IntegerType()))
    df = normalize_timestamp(df)
    df = df.dropna(subset=["heart_rate", "timestamp"])
    df = df.filter((col("heart_rate") > 0) & (col("heart_rate") < 300))
    logger.info("Heart rate cleaning complete (streaming mode).")
    return df


def clean_calories(df):
    logger.info("Cleaning calories stream...")
    df = df.withColumn("calories", col("calories").cast(DoubleType()))
    df = normalize_timestamp(df)
    df = df.dropna(subset=["calories", "timestamp"])
    df = df.filter(col("calories") >= 0)
    logger.info("Calories cleaning complete (streaming mode).")
    return df


def clean_steps(df):
    logger.info("Cleaning steps stream...")
    df = df.withColumn("steps", col("steps").cast(IntegerType()))
    df = normalize_timestamp(df)
    df = df.dropna(subset=["steps", "timestamp"])
    df = df.filter(col("steps") >= 0)
    logger.info("Steps cleaning complete (streaming mode).")
    return df
    

  
# ---------- prepare streams ----------

heart_rate_df = read_topic("heartrate", heart_rate_schema)
calories_df = read_topic("calories", calories_schema)
steps_df = read_topic("steps", steps_schema)

hr_clean = clean_heart_rate(heart_rate_df)
cal_clean = clean_calories(calories_df)
st_clean = clean_steps(steps_df)
# Out:
# [2025-11-06 09:37:11,530] INFO - Cleaning heart rate stream...
# [2025-11-06 09:37:11,572] INFO - Normalizing timestamp — candidates: ['time']
# [2025-11-06 09:37:11,573] INFO - Using 'time' as timestamp source.
# [2025-11-06 09:37:11,649] INFO - Heart rate cleaning complete (streaming mode).
# [2025-11-06 09:37:11,650] INFO - Cleaning calories stream...
# [2025-11-06 09:37:11,674] INFO - Normalizing timestamp — candidates: ['time']
# [2025-11-06 09:37:11,675] INFO - Using 'time' as timestamp source.
# [2025-11-06 09:37:11,740] INFO - Calories cleaning complete (streaming mode).
# [2025-11-06 09:37:11,741] INFO - Cleaning steps stream...
# [2025-11-06 09:37:11,758] INFO - Normalizing timestamp — candidates: ['time']
# [2025-11-06 09:37:11,759] INFO - Using 'time' as timestamp source.
# [2025-11-06 09:37:11,832] INFO - Steps cleaning complete (streaming mode).

# %% [markdown]
# ## anomaly detection functions

# %%
import time
from datetime import datetime

def send_alert_to_firestore(user_id, alert_type, value, firestore_client,timestamp):
    """
    Write an anomaly alert to Firestore.
    Each alert becomes a document in the 'alerts' collection.

    Args:
        user_id (str): The ID of the affected user.
        alert_type (str): Type of the alert, e.g., 'heart_rate', 'calories', etc.
        firestore_client: Initialized Firestore client (google.cloud.firestore.Client).
    """
    try:
        alerts_ref = firestore_client.collection("alerts")
        alert_doc = {
            "user_id": user_id,
            "type": alert_type,
            "value": value,
            "detected_at": timestamp,
            "alert_created_at_unix": int(time.time()),
            "status":"waiting"
        }

        alerts_ref.add(alert_doc)
        print(f"[ok] Alert written for user={user_id}: {alert_type} — {value}")

    except Exception as e:
        print(f"[error] Failed to write alert for user={user_id}: {e}")
        
def detect_heart_rate_anomalies(df, firestore_client):
    anomalies = df.filter((col("heart_rate") > 180) | (col("heart_rate") < 45))
    if anomalies.rdd.isEmpty():
        return
    for row in anomalies.toLocalIterator():
        send_alert_to_firestore(
            user_id=row.user_id,
            alert_type="heart_rate",
            value=row.heart_rate,
            firestore_client=firestore_client,
            timestamp= row.timestamp
        )
        
def detect_low_calories(df, firestore_client):
    low_activity = df.filter(col("calories") < 0.5)  # e.g. less than 0.5 kcal/min or similar
    if low_activity.rdd.isEmpty():
        return
    for row in low_activity.toLocalIterator():
        send_alert_to_firestore(
            user_id=row.user_id,
            alert_type="low_calories",
            value=row.calories,
            firestore_client=firestore_client,
            timestamp= row.timestamp
        )
        
def detect_inactivity(df, firestore_client):
    inactive = df.filter(col("steps") == 0)
    if inactive.rdd.isEmpty():
        return
    for row in inactive.toLocalIterator():
        send_alert_to_firestore(
            user_id=row.user_id,
            alert_type="inactivity",
            value=0,
            firestore_client=firestore_client,
            timestamp= row.timestamp
        )

# %% [markdown]
# ## write stream functions

# %%
import logging
import time
import datetime
import decimal
import json
from google.api_core.exceptions import GoogleAPICallError, RetryError

# logger (reuse your existing logger or this)
fs_logger = logging.getLogger("firestore-writer")
fs_logger.setLevel(logging.INFO)
if not fs_logger.hasHandlers():
    h = logging.StreamHandler()
    h.setFormatter(logging.Formatter("[%(levelname)s] %(asctime)s - %(message)s"))
    fs_logger.addHandler(h)


def _serialize_value(v):
    """Make values Firestore-safe: datetime -> ISO, Decimal -> float, fallback to str for non-JSON."""
    if v is None:
        return None
    if isinstance(v, (datetime.datetime, datetime.date)):
        return v.isoformat()
    if isinstance(v, decimal.Decimal):
        return float(v)
    # Bytes -> decode
    if isinstance(v, (bytes, bytearray)):
        try:
            return v.decode()
        except Exception:
            return str(v)
    # Test JSON-serializable quickly
    try:
        json.dumps(v)
        return v
    except Exception:
        return str(v)


def _commit_with_retries(batch_obj, max_retries=3, base_backoff=0.5):
    """Commit a Firestore batch with retries on transient errors."""
    attempt = 0
    while True:
        try:
            batch_obj.commit()
            return
        except (GoogleAPICallError, RetryError, IOError) as e:
            attempt += 1
            if attempt > max_retries:
                fs_logger.exception("Firestore commit failed after %d attempts", attempt - 1)
                raise
            backoff = base_backoff * (2 ** (attempt - 1))
            fs_logger.warning("Transient error committing firestore batch (attempt %d). Backing off %.2fs. Error: %s",
                              attempt, backoff, str(e))
            time.sleep(backoff)


def make_firestore_writer(collection_name, firestore_client, batch_size=500, max_retries=3):
    """
    Writes to Firestore under this structure:
      users/{user_id}/{collection_name}/{auto_doc_id}

    collection_name: e.g. "heart_rate", "calories", "steps"
    """
    def write_batch_to_firestore(batch_df, epoch_id):
        epoch_str = str(epoch_id) if epoch_id is not None else "(no-epoch)"
        try:
            rows = batch_df.count()
        except Exception as e:
            fs_logger.exception("[epoch %s] failed to count batch: %s", epoch_str, e)
            rows = None

        if not rows:
            fs_logger.info("[epoch %s] empty, skipping collection=%s", epoch_str, collection_name)
            return

        fs_logger.info("[epoch %s] writing %s rows to Firestore subcollections '%s'", epoch_str, rows, collection_name)

        docs_written = 0
        ops_in_current_batch = 0
        fs_batch = firestore_client.batch()

        try:
            for row in batch_df.toLocalIterator():
                data = row.asDict(recursive=True)
                user_id = data.get("user_id")

                if not user_id:
                    fs_logger.warning("[epoch %s] skipping row without user_id: %s", epoch_str, data)
                    continue

                # Serialize all values to Firestore-safe types
                for k, v in list(data.items()):
                    data[k] = _serialize_value(v)

                # Path: users/{user_id}/{collection_name}/{auto_doc_id}
                doc_ref = (
                    firestore_client.collection("users")
                    .document(str(user_id))
                    .collection(collection_name)
                    .document()
                )

                fs_batch.set(doc_ref, data)
                ops_in_current_batch += 1

                if ops_in_current_batch >= batch_size:
                    _commit_with_retries(fs_batch, max_retries=max_retries)
                    docs_written += ops_in_current_batch
                    ops_in_current_batch = 0
                    fs_batch = firestore_client.batch()

            if ops_in_current_batch > 0:
                _commit_with_retries(fs_batch, max_retries=max_retries)
                docs_written += ops_in_current_batch

            fs_logger.info("[epoch %s] wrote %d docs under users/*/%s/", epoch_str, docs_written, collection_name)

        except Exception as e:
            fs_logger.exception("[epoch %s] Firestore write failed: %s", epoch_str, e)
            raise

    return write_batch_to_firestore

# %% [markdown]
# ## cleaning stream queries

# %%
# start streams separately with their own checkpoints
# Pass the initialized Firestore client 'db' to your writer functions
hr_query = (
    hr_clean
    .writeStream
    .foreachBatch(make_firestore_writer("heart_rate", db)) # Pass the Firestore client here
    .option("checkpointLocation", f"{CHECKPOINT_BASE}/heart_rate")
    .outputMode("append")
    .start()
)
cal_clean.writeStream.format("console").outputMode("append").start()

cal_query = (
    cal_clean
    .writeStream
    .foreachBatch(make_firestore_writer("calories", db)) # Pass the Firestore client here
    .option("checkpointLocation", f"{CHECKPOINT_BASE}/calories")
    .outputMode("append")
    .start()
)

st_query = (
    st_clean
    .writeStream
    .foreachBatch(make_firestore_writer("steps", db)) # Pass the Firestore client here
    .option("checkpointLocation", f"{CHECKPOINT_BASE}/steps")
    .outputMode("append")
    .start()
)
# Start streams for each detection type
hr_alerts = (
    hr_clean.writeStream
    .foreachBatch(lambda batch_df, epoch_id: detect_heart_rate_anomalies(batch_df, db))
    .option("checkpointLocation", f"{CHECKPOINT_BASE}/alerts_hr")
    .start()
)

cal_alerts = (
    cal_clean.writeStream
    .foreachBatch(lambda batch_df, epoch_id: detect_low_calories(batch_df, db))
    .option("checkpointLocation", f"{CHECKPOINT_BASE}/alerts_calories")
    .start()
)

st_alerts = (
    st_clean.writeStream
    .foreachBatch(lambda batch_df, epoch_id: detect_inactivity(batch_df, db))
    .option("checkpointLocation", f"{CHECKPOINT_BASE}/alerts_steps")
    .start()
)

spark.streams.awaitAnyTermination()


print("Started all streams. Waiting...")
spark.streams.awaitAnyTermination()
# Out:
# Started all streams. Waiting...
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +-------+--------+---------+
# |user_id|calories|timestamp|
# +-------+--------+---------+
# +-------+--------+---------+
# [INFO] 2025-11-06 09:38:29,947 - [epoch 2741] starting write: collection=heart_rate rows=1022
# [INFO] 2025-11-06 09:38:30,164 - [epoch 55] starting write: collection=steps rows=17
# [INFO] 2025-11-06 09:38:30,188 - [epoch 55] starting write: collection=calories rows=17
# [INFO] 2025-11-06 09:38:31,501 - [epoch 55] wrote 17 documents to Firestore collection=steps
# [INFO] 2025-11-06 09:38:31,630 - [epoch 55] wrote 17 documents to Firestore collection=calories
# [ok] Alert written for user=4702921684: inactivity — 0
# [ok] Alert written for user=6290855005: inactivity — 0
# [ok] Alert written for user=5553957443: inactivity — 0
# [ok] Alert written for user=8583815059: inactivity — 0
# [ok] Alert written for user=5577150313: inactivity — 0
# [ok] Alert written for user=1503960366: inactivity — 0
# [ok] Alert written for user=8378563200: inactivity — 0
# [ok] Alert written for user=1644430081: inactivity — 0
# [INFO] 2025-11-06 09:38:33,095 - [epoch 2741] wrote 1022 documents to Firestore collection=heart_rate
# [ok] Alert written for user=1844505072: inactivity — 0
# [ok] Alert written for user=1927972279: inactivity — 0
# [ok] Alert written for user=8053475328: inactivity — 0
# [ok] Alert written for user=2022484408: inactivity — 0
# [ok] Alert written for user=8877689391: inactivity — 0
# [ok] Alert written for user=2026352035: inactivity — 0
# [INFO] 2025-11-06 09:38:33,793 - [epoch 2742] starting write: collection=heart_rate rows=4
# [ok] Alert written for user=7086361926: inactivity — 0
# [ok] Alert written for user=2320127002: inactivity — 0
# [ok] Alert written for user=2347167796: inactivity — 0
# [INFO] 2025-11-06 09:38:34,525 - [epoch 2742] wrote 4 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:34,771 - [epoch 2743] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:34,959 - [epoch 2743] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:35,613 - [epoch 2744] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:35,920 - [epoch 2744] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:36,555 - [epoch 2745] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:36,940 - [epoch 2745] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:37,698 - [epoch 2746] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:37,992 - [epoch 2746] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:38,641 - [epoch 2747] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:38,932 - [epoch 2747] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:39,536 - [epoch 2748] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:39,934 - [epoch 2748] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:40,540 - [epoch 2749] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:40,941 - [epoch 2749] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:41,608 - [epoch 2750] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:42,011 - [epoch 2750] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:42,667 - [epoch 2751] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:42,966 - [epoch 2751] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:43,666 - [epoch 2752] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:43,987 - [epoch 2752] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:44,627 - [epoch 2753] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:44,998 - [epoch 2753] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:45,662 - [epoch 2754] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:45,991 - [epoch 2754] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:46,692 - [epoch 2755] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:46,999 - [epoch 2755] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:47,615 - [epoch 2756] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:48,024 - [epoch 2756] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:48,671 - [epoch 2757] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:48,999 - [epoch 2757] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:49,663 - [epoch 2758] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:49,991 - [epoch 2758] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:50,634 - [epoch 2759] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:51,000 - [epoch 2759] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:51,641 - [epoch 2760] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:51,990 - [epoch 2760] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:52,636 - [epoch 2761] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:53,002 - [epoch 2761] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:53,669 - [epoch 2762] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:54,011 - [epoch 2762] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:54,641 - [epoch 2763] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:55,011 - [epoch 2763] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:55,616 - [epoch 2764] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:56,153 - [epoch 2764] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:56,865 - [epoch 2765] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:57,540 - [epoch 2765] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:57,920 - [epoch 2766] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:58,096 - [epoch 2766] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:58,714 - [epoch 2767] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:38:59,045 - [epoch 2767] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:38:59,671 - [epoch 2768] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:00,080 - [epoch 2768] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:00,760 - [epoch 56] starting write: collection=calories rows=1
# [INFO] 2025-11-06 09:39:00,771 - [epoch 56] starting write: collection=steps rows=1
# [INFO] 2025-11-06 09:39:00,849 - [epoch 2769] starting write: collection=heart_rate rows=1
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +----------+----------------+-------------------+
# |   user_id|        calories|          timestamp|
# +----------+----------------+-------------------+
# |2873212765|0.87830001115799|2016-04-12 00:00:00|
# +----------+----------------+-------------------+
# [INFO] 2025-11-06 09:39:01,076 - [epoch 2769] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:01,512 - [epoch 56] wrote 1 documents to Firestore collection=calories
# [INFO] 2025-11-06 09:39:01,521 - [epoch 56] wrote 1 documents to Firestore collection=steps
# [ok] Alert written for user=2873212765: inactivity — 0
# [INFO] 2025-11-06 09:39:01,705 - [epoch 2770] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:02,074 - [epoch 2770] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:02,703 - [epoch 2771] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:03,081 - [epoch 2771] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:03,700 - [epoch 2772] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:04,091 - [epoch 2772] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:04,733 - [epoch 2773] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:05,091 - [epoch 2773] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:05,687 - [epoch 2774] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:06,101 - [epoch 2774] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:06,695 - [epoch 2775] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:07,103 - [epoch 2775] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:07,746 - [epoch 2776] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:08,116 - [epoch 2776] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:08,716 - [epoch 2777] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:09,140 - [epoch 2777] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:09,725 - [epoch 2778] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:10,132 - [epoch 2778] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:10,742 - [epoch 2779] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:11,161 - [epoch 2779] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:11,771 - [epoch 2780] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:12,142 - [epoch 2780] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:12,729 - [epoch 2781] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:13,253 - [epoch 2781] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:13,832 - [epoch 2782] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:14,150 - [epoch 2782] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:14,726 - [epoch 2783] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:15,176 - [epoch 2783] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:15,764 - [epoch 2784] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:16,179 - [epoch 2784] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:16,780 - [epoch 2785] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:17,213 - [epoch 2785] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:17,841 - [epoch 2786] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:18,233 - [epoch 2786] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:18,846 - [epoch 2787] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:19,212 - [epoch 2787] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:19,861 - [epoch 2788] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:20,193 - [epoch 2788] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:20,813 - [epoch 2789] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:21,194 - [epoch 2789] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:21,807 - [epoch 2790] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:22,211 - [epoch 2790] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:22,842 - [epoch 2791] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:23,258 - [epoch 2791] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:23,890 - [epoch 2792] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:24,267 - [epoch 2792] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:24,892 - [epoch 2793] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:25,297 - [epoch 2793] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:25,950 - [epoch 2794] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:26,229 - [epoch 2794] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:26,962 - [epoch 2795] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:27,222 - [epoch 2795] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:27,826 - [epoch 2796] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:28,240 - [epoch 2796] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:28,829 - [epoch 2797] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:29,248 - [epoch 2797] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:29,833 - [epoch 2798] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:30,243 - [epoch 2798] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:30,818 - [epoch 2799] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:31,349 - [epoch 2799] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:31,924 - [epoch 2800] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:32,259 - [epoch 2800] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:32,844 - [epoch 2801] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:33,247 - [epoch 2801] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:33,832 - [epoch 2802] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:34,255 - [epoch 2802] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:34,828 - [epoch 2803] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:35,270 - [epoch 2803] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:35,848 - [epoch 2804] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:36,281 - [epoch 2804] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:36,859 - [epoch 2805] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:37,276 - [epoch 2805] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:37,850 - [epoch 2806] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:38,269 - [epoch 2806] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:38,845 - [epoch 2807] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:39,282 - [epoch 2807] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:39,855 - [epoch 2808] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:40,336 - [epoch 2808] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:40,915 - [epoch 2809] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:41,293 - [epoch 2809] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:41,865 - [epoch 2810] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:42,295 - [epoch 2810] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:42,874 - [epoch 2811] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:43,304 - [epoch 2811] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:43,894 - [epoch 2812] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:44,299 - [epoch 2812] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:44,871 - [epoch 2813] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:45,319 - [epoch 2813] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:45,892 - [epoch 2814] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:46,308 - [epoch 2814] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:46,887 - [epoch 2815] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:47,323 - [epoch 2815] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:47,897 - [epoch 2816] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:48,355 - [epoch 2816] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:48,928 - [epoch 2817] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:49,334 - [epoch 2817] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:49,906 - [epoch 2818] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:50,325 - [epoch 2818] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:50,898 - [epoch 2819] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:51,447 - [epoch 2819] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:52,020 - [epoch 2820] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:52,360 - [epoch 2820] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:52,932 - [epoch 2821] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:53,340 - [epoch 2821] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:53,913 - [epoch 2822] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:54,359 - [epoch 2822] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:54,931 - [epoch 2823] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:55,393 - [epoch 2823] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:55,993 - [epoch 2824] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:56,380 - [epoch 2824] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:56,963 - [epoch 2825] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:57,447 - [epoch 2825] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:58,017 - [epoch 2826] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:58,361 - [epoch 2826] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:58,938 - [epoch 2827] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:39:59,394 - [epoch 2827] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:39:59,981 - [epoch 2828] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:00,399 - [epoch 2828] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:00,653 - [epoch 57] starting write: collection=calories rows=1
# [INFO] 2025-11-06 09:40:00,677 - [epoch 57] starting write: collection=steps rows=1
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +----------+----------------+-------------------+
# |   user_id|        calories|          timestamp|
# +----------+----------------+-------------------+
# |7007744171|1.08120000362396|2016-04-12 00:00:00|
# +----------+----------------+-------------------+
# [INFO] 2025-11-06 09:40:00,983 - [epoch 2829] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:01,311 - [epoch 57] wrote 1 documents to Firestore collection=calories
# [INFO] 2025-11-06 09:40:01,337 - [epoch 57] wrote 1 documents to Firestore collection=steps
# [INFO] 2025-11-06 09:40:01,388 - [epoch 2829] wrote 1 documents to Firestore collection=heart_rate
# [ok] Alert written for user=7007744171: inactivity — 0
# [INFO] 2025-11-06 09:40:01,964 - [epoch 2830] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:02,470 - [epoch 2830] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:03,040 - [epoch 2831] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:03,408 - [epoch 2831] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:03,978 - [epoch 2832] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:04,416 - [epoch 2832] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:04,991 - [epoch 2833] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:05,425 - [epoch 2833] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:05,994 - [epoch 2834] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:06,413 - [epoch 2834] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:06,985 - [epoch 2835] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:07,431 - [epoch 2835] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:08,004 - [epoch 2836] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:08,426 - [epoch 2836] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:08,996 - [epoch 2837] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:09,439 - [epoch 2837] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:10,007 - [epoch 2838] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:10,462 - [epoch 2838] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:11,034 - [epoch 2839] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:11,453 - [epoch 2839] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:12,024 - [epoch 2840] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:12,514 - [epoch 2840] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:13,082 - [epoch 2841] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:13,530 - [epoch 2841] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:14,102 - [epoch 2842] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:14,463 - [epoch 2842] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:15,033 - [epoch 2843] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:15,496 - [epoch 2843] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:16,089 - [epoch 2844] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:16,471 - [epoch 2844] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:17,043 - [epoch 2845] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:17,471 - [epoch 2845] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:18,089 - [epoch 2846] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:18,521 - [epoch 2846] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:19,135 - [epoch 2847] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:19,497 - [epoch 2847] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:20,094 - [epoch 2848] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:20,499 - [epoch 2848] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:21,097 - [epoch 2849] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:21,500 - [epoch 2849] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:22,077 - [epoch 2850] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:22,515 - [epoch 2850] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:23,099 - [epoch 2851] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:23,506 - [epoch 2851] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:24,091 - [epoch 2852] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:24,541 - [epoch 2852] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:25,135 - [epoch 2853] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:25,629 - [epoch 2853] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:26,205 - [epoch 2854] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:26,528 - [epoch 2854] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:27,126 - [epoch 2855] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:27,553 - [epoch 2855] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:28,152 - [epoch 2856] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:28,538 - [epoch 2856] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:29,107 - [epoch 2857] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:29,614 - [epoch 2857] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:30,182 - [epoch 2858] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:30,635 - [epoch 2858] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:31,209 - [epoch 2859] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:31,549 - [epoch 2859] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:32,223 - [epoch 2860] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:32,571 - [epoch 2860] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:33,145 - [epoch 2861] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:33,549 - [epoch 2861] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:34,134 - [epoch 2862] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:34,558 - [epoch 2862] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:35,146 - [epoch 2863] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:35,571 - [epoch 2863] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:36,180 - [epoch 2864] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:36,573 - [epoch 2864] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:37,150 - [epoch 2865] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:37,575 - [epoch 2865] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:38,144 - [epoch 2866] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:38,615 - [epoch 2866] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:39,187 - [epoch 2867] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:39,642 - [epoch 2867] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:40,217 - [epoch 2868] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:40,908 - [epoch 2868] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:41,467 - [epoch 2869] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:42,112 - [epoch 2869] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:42,471 - [epoch 2870] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:42,616 - [epoch 2870] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:43,205 - [epoch 2871] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:43,610 - [epoch 2871] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:44,187 - [epoch 2872] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:44,602 - [epoch 2872] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:45,178 - [epoch 2873] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:45,689 - [epoch 2873] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:46,263 - [epoch 2874] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:46,617 - [epoch 2874] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:47,199 - [epoch 2875] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:47,646 - [epoch 2875] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:48,240 - [epoch 2876] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:48,615 - [epoch 2876] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:49,188 - [epoch 2877] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:49,627 - [epoch 2877] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:50,228 - [epoch 2878] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:50,679 - [epoch 2878] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:51,286 - [epoch 2879] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:51,730 - [epoch 2879] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:52,309 - [epoch 2880] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:52,645 - [epoch 2880] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:53,221 - [epoch 2881] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:53,811 - [epoch 2881] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:54,391 - [epoch 2882] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:54,646 - [epoch 2882] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:55,226 - [epoch 2883] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:55,642 - [epoch 2883] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:56,219 - [epoch 2884] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:56,659 - [epoch 2884] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:57,232 - [epoch 2885] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:57,656 - [epoch 2885] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:58,227 - [epoch 2886] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:58,664 - [epoch 2886] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:40:59,239 - [epoch 2887] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:40:59,677 - [epoch 2887] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:00,248 - [epoch 2888] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:00,643 - [epoch 58] starting write: collection=calories rows=1
# [INFO] 2025-11-06 09:41:00,677 - [epoch 58] starting write: collection=steps rows=1
# [INFO] 2025-11-06 09:41:00,734 - [epoch 2888] wrote 1 documents to Firestore collection=heart_rate
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +----------+----------------+-------------------+
# |   user_id|        calories|          timestamp|
# +----------+----------------+-------------------+
# |3372868164|0.93529999256134|2016-04-12 00:00:00|
# +----------+----------------+-------------------+
# [INFO] 2025-11-06 09:41:01,308 - [epoch 2889] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:01,312 - [epoch 58] wrote 1 documents to Firestore collection=calories
# [INFO] 2025-11-06 09:41:01,345 - [epoch 58] wrote 1 documents to Firestore collection=steps
# [ok] Alert written for user=3372868164: inactivity — 0
# [INFO] 2025-11-06 09:41:01,695 - [epoch 2889] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:02,267 - [epoch 2890] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:02,687 - [epoch 2890] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:03,259 - [epoch 2891] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:03,699 - [epoch 2891] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:04,271 - [epoch 2892] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:04,700 - [epoch 2892] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:05,307 - [epoch 2893] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:05,714 - [epoch 2893] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:06,286 - [epoch 2894] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:06,704 - [epoch 2894] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:07,280 - [epoch 2895] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:07,843 - [epoch 2895] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:08,430 - [epoch 2896] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:08,744 - [epoch 2896] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:09,318 - [epoch 2897] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:09,777 - [epoch 2897] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:10,352 - [epoch 2898] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:10,760 - [epoch 2898] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:11,342 - [epoch 2899] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:11,744 - [epoch 2899] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:12,338 - [epoch 2900] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:12,755 - [epoch 2900] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:13,327 - [epoch 2901] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:13,737 - [epoch 2901] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:14,313 - [epoch 2902] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:14,750 - [epoch 2902] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:15,324 - [epoch 2903] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:15,931 - [epoch 2903] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:16,506 - [epoch 2904] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:16,802 - [epoch 2904] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:17,389 - [epoch 2905] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:17,830 - [epoch 2905] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:18,411 - [epoch 2906] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:18,771 - [epoch 2906] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:19,345 - [epoch 2907] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:19,768 - [epoch 2907] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:20,357 - [epoch 2908] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:20,814 - [epoch 2908] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:21,406 - [epoch 2909] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:21,782 - [epoch 2909] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:22,357 - [epoch 2910] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:22,782 - [epoch 2910] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:23,382 - [epoch 2911] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:23,854 - [epoch 2911] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:24,431 - [epoch 2912] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:24,814 - [epoch 2912] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:25,382 - [epoch 2913] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:25,965 - [epoch 2913] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:26,532 - [epoch 2914] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:26,830 - [epoch 2914] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:27,397 - [epoch 2915] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:27,836 - [epoch 2915] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:28,422 - [epoch 2916] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:28,816 - [epoch 2916] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:29,387 - [epoch 2917] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:29,941 - [epoch 2917] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:30,539 - [epoch 2918] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:30,833 - [epoch 2918] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:31,400 - [epoch 2919] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:31,890 - [epoch 2919] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:32,482 - [epoch 2920] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:32,909 - [epoch 2920] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:33,501 - [epoch 2921] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:33,858 - [epoch 2921] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:34,426 - [epoch 2922] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:34,947 - [epoch 2922] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:35,518 - [epoch 2923] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:35,879 - [epoch 2923] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:36,447 - [epoch 2924] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:36,870 - [epoch 2924] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:37,449 - [epoch 2925] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:37,927 - [epoch 2925] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:38,501 - [epoch 2926] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:38,866 - [epoch 2926] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:39,435 - [epoch 2927] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:39,969 - [epoch 2927] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:40,536 - [epoch 2928] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:40,883 - [epoch 2928] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:41,451 - [epoch 2929] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:41,906 - [epoch 2929] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:42,476 - [epoch 2930] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:42,935 - [epoch 2930] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:43,500 - [epoch 2931] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:43,969 - [epoch 2931] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:44,536 - [epoch 2932] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:44,897 - [epoch 2932] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:45,467 - [epoch 2933] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:45,919 - [epoch 2933] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:46,490 - [epoch 2934] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:46,928 - [epoch 2934] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:47,496 - [epoch 2935] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:47,907 - [epoch 2935] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:48,473 - [epoch 2936] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:48,916 - [epoch 2936] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:49,485 - [epoch 2937] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:50,015 - [epoch 2937] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:50,580 - [epoch 2938] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:50,918 - [epoch 2938] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:51,500 - [epoch 2939] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:51,917 - [epoch 2939] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:52,484 - [epoch 2940] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:52,975 - [epoch 2940] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:53,553 - [epoch 2941] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:53,989 - [epoch 2941] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:54,556 - [epoch 2942] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:54,952 - [epoch 2942] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:55,521 - [epoch 2943] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:56,051 - [epoch 2943] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:56,619 - [epoch 2944] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:56,956 - [epoch 2944] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:57,541 - [epoch 2945] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:57,951 - [epoch 2945] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:58,520 - [epoch 2946] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:58,955 - [epoch 2946] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:41:59,521 - [epoch 2947] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:41:59,961 - [epoch 2947] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:42:00,535 - [epoch 2948] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:42:00,627 - [epoch 59] starting write: collection=steps rows=1
# [INFO] 2025-11-06 09:42:00,632 - [epoch 59] starting write: collection=calories rows=1
# -------------------------------------------
# Batch: 4
# -------------------------------------------
# +----------+----------------+-------------------+
# |   user_id|        calories|          timestamp|
# +----------+----------------+-------------------+
# |3977333714|8.08104991912842|2016-04-12 00:00:00|
# +----------+----------------+-------------------+
# [INFO] 2025-11-06 09:42:00,959 - [epoch 2948] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:42:01,285 - [epoch 59] wrote 1 documents to Firestore collection=steps
# [INFO] 2025-11-06 09:42:01,307 - [epoch 59] wrote 1 documents to Firestore collection=calories
# [INFO] 2025-11-06 09:42:01,524 - [epoch 2949] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:42:01,979 - [epoch 2949] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:42:02,545 - [epoch 2950] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:42:02,978 - [epoch 2950] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:42:03,547 - [epoch 2951] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:42:03,984 - [epoch 2951] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:42:04,550 - [epoch 2952] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:42:04,978 - [epoch 2952] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:42:05,547 - [epoch 2953] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:42:05,988 - [epoch 2953] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:42:06,552 - [epoch 2954] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:42:06,989 - [epoch 2954] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:42:07,556 - [epoch 2955] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:42:08,007 - [epoch 2955] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:42:08,573 - [epoch 2956] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:42:09,009 - [epoch 2956] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:42:09,585 - [epoch 2957] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:42:10,019 - [epoch 2957] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:42:10,585 - [epoch 2958] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:42:11,027 - [epoch 2958] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:42:11,593 - [epoch 2959] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:42:12,044 - [epoch 2959] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:42:12,612 - [epoch 2960] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:42:13,046 - [epoch 2960] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:42:13,655 - [epoch 2961] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:42:14,040 - [epoch 2961] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:42:14,618 - [epoch 2962] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:42:15,048 - [epoch 2962] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:42:15,624 - [epoch 2963] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:42:16,041 - [epoch 2963] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:42:16,613 - [epoch 2964] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:42:17,054 - [epoch 2964] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:42:17,631 - [epoch 2965] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:42:18,056 - [epoch 2965] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:42:18,629 - [epoch 2966] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:42:19,053 - [epoch 2966] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:42:19,633 - [epoch 2967] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:42:20,065 - [epoch 2967] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:42:20,646 - [epoch 2968] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:42:21,078 - [epoch 2968] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:42:21,649 - [epoch 2969] starting write: collection=heart_rate rows=1
# ...
# [INFO] 2025-11-06 09:51:28,839 - [epoch 3513] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:29,405 - [epoch 3514] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:29,850 - [epoch 3514] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:30,408 - [epoch 3515] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:30,854 - [epoch 3515] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:31,418 - [epoch 3516] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:31,858 - [epoch 3516] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:32,417 - [epoch 3517] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:32,854 - [epoch 3517] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:33,414 - [epoch 3518] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:33,857 - [epoch 3518] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:34,419 - [epoch 3519] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:34,875 - [epoch 3519] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:35,443 - [epoch 3520] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:35,873 - [epoch 3520] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:36,436 - [epoch 3521] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:36,897 - [epoch 3521] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:37,466 - [epoch 3522] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:37,880 - [epoch 3522] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:38,439 - [epoch 3523] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:38,894 - [epoch 3523] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:39,453 - [epoch 3524] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:39,893 - [epoch 3524] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:40,452 - [epoch 3525] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:40,891 - [epoch 3525] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:41,453 - [epoch 3526] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:41,896 - [epoch 3526] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:42,456 - [epoch 3527] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:42,907 - [epoch 3527] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:43,491 - [epoch 3528] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:43,911 - [epoch 3528] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:44,473 - [epoch 3529] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:44,920 - [epoch 3529] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:45,480 - [epoch 3530] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:45,925 - [epoch 3530] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:46,487 - [epoch 3531] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:46,925 - [epoch 3531] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:47,528 - [epoch 3532] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:47,937 - [epoch 3532] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:48,496 - [epoch 3533] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:48,935 - [epoch 3533] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:49,496 - [epoch 3534] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:49,937 - [epoch 3534] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:50,495 - [epoch 3535] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:50,953 - [epoch 3535] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:51,524 - [epoch 3536] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:51,959 - [epoch 3536] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:52,518 - [epoch 3537] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:52,950 - [epoch 3537] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:53,520 - [epoch 3538] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:53,966 - [epoch 3538] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:54,530 - [epoch 3539] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:54,972 - [epoch 3539] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:55,533 - [epoch 3540] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:55,977 - [epoch 3540] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:56,537 - [epoch 3541] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:56,976 - [epoch 3541] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:57,543 - [epoch 3542] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:57,983 - [epoch 3542] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:58,540 - [epoch 3543] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:51:58,991 - [epoch 3543] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:51:59,552 - [epoch 3544] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:00,004 - [epoch 3544] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:00,565 - [epoch 3545] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:00,650 - [epoch 69] starting write: collection=calories rows=1
# [INFO] 2025-11-06 09:52:00,651 - [epoch 69] starting write: collection=steps rows=1
# -------------------------------------------
# Batch: 14
# -------------------------------------------
# +----------+----------------+-------------------+
# |   user_id|        calories|          timestamp|
# +----------+----------------+-------------------+
# |4702921684|1.40079998970032|2016-04-12 00:00:00|
# +----------+----------------+-------------------+
# [INFO] 2025-11-06 09:52:01,022 - [epoch 3545] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:01,314 - [epoch 69] wrote 1 documents to Firestore collection=steps
# [INFO] 2025-11-06 09:52:01,317 - [epoch 69] wrote 1 documents to Firestore collection=calories
# [ok] Alert written for user=4702921684: inactivity — 0
# [INFO] 2025-11-06 09:52:01,612 - [epoch 3546] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:02,012 - [epoch 3546] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:02,583 - [epoch 3547] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:03,029 - [epoch 3547] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:03,588 - [epoch 3548] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:04,025 - [epoch 3548] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:04,587 - [epoch 3549] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:05,030 - [epoch 3549] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:05,588 - [epoch 3550] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:06,029 - [epoch 3550] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:06,593 - [epoch 3551] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:07,044 - [epoch 3551] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:07,604 - [epoch 3552] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:08,050 - [epoch 3552] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:08,638 - [epoch 3553] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:09,050 - [epoch 3553] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:09,633 - [epoch 3554] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:10,065 - [epoch 3554] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:10,642 - [epoch 3555] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:11,069 - [epoch 3555] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:11,632 - [epoch 3556] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:12,061 - [epoch 3556] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:12,631 - [epoch 3557] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:13,083 - [epoch 3557] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:13,648 - [epoch 3558] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:14,080 - [epoch 3558] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:14,653 - [epoch 3559] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:15,083 - [epoch 3559] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:15,648 - [epoch 3560] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:16,086 - [epoch 3560] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:16,655 - [epoch 3561] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:17,104 - [epoch 3561] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:17,671 - [epoch 3562] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:18,104 - [epoch 3562] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:18,670 - [epoch 3563] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:19,101 - [epoch 3563] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:19,666 - [epoch 3564] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:20,159 - [epoch 3564] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:20,724 - [epoch 3565] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:21,127 - [epoch 3565] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:21,704 - [epoch 3566] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:22,117 - [epoch 3566] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:22,703 - [epoch 3567] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:23,131 - [epoch 3567] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:23,709 - [epoch 3568] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:24,123 - [epoch 3568] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:24,692 - [epoch 3569] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:25,131 - [epoch 3569] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:25,712 - [epoch 3570] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:26,144 - [epoch 3570] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:26,720 - [epoch 3571] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:27,150 - [epoch 3571] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:27,717 - [epoch 3572] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:28,144 - [epoch 3572] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:28,711 - [epoch 3573] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:29,154 - [epoch 3573] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:29,717 - [epoch 3574] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:30,157 - [epoch 3574] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:30,723 - [epoch 3575] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:31,152 - [epoch 3575] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:31,714 - [epoch 3576] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:32,170 - [epoch 3576] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:32,744 - [epoch 3577] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:33,177 - [epoch 3577] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:33,762 - [epoch 3578] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:34,177 - [epoch 3578] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:34,773 - [epoch 3579] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:35,189 - [epoch 3579] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:35,757 - [epoch 3580] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:36,189 - [epoch 3580] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:36,753 - [epoch 3581] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:37,185 - [epoch 3581] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:37,749 - [epoch 3582] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:38,195 - [epoch 3582] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:38,761 - [epoch 3583] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:39,205 - [epoch 3583] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:39,771 - [epoch 3584] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:40,204 - [epoch 3584] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:40,768 - [epoch 3585] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:41,209 - [epoch 3585] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:41,769 - [epoch 3586] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:42,224 - [epoch 3586] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:42,802 - [epoch 3587] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:43,228 - [epoch 3587] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:43,798 - [epoch 3588] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:44,232 - [epoch 3588] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:44,797 - [epoch 3589] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:45,236 - [epoch 3589] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:45,808 - [epoch 3590] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:46,246 - [epoch 3590] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:46,809 - [epoch 3591] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:47,249 - [epoch 3591] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:47,832 - [epoch 3592] starting write: collection=heart_rate rows=1
# [INFO] 2025-11-06 09:52:48,250 - [epoch 3592] wrote 1 documents to Firestore collection=heart_rate
# [INFO] 2025-11-06 09:52:48,809 - [epoch 3593] starting write: collection=heart_rate rows=1

# %%
for q in spark.streams.active:
    q.stop()
print("✅ Stopped all active queries.")
# Out:
# ✅ Stopped all active queries.
