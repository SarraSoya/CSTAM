# %% [markdown]
# ## firebase setup

# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore
import os

SERVICE_ACCOUNT_KEY_PATH = os.environ.get("FIREBASE_SERVICE_ACCOUNT_KEY_PATH", "./cstam2-1f2ec-firebase-adminsdk-fbsvc-2ab61a7ed6.json")

try:
    # Check if the default app is already initialized
    app = firebase_admin.get_app()
    print("Firebase Admin SDK already initialized. Reusing existing app instance.")
except ValueError:
    # If not initialized, proceed with initialization
    try:
        cred = credentials.Certificate(SERVICE_ACCOUNT_KEY_PATH)
        app = firebase_admin.initialize_app(cred)
        print("Firebase Admin SDK initialized successfully.")
    except Exception as e:
        print(f"Error during Firebase Admin SDK initialization: {e}")
        # It's crucial to handle this error, as your app can't write to Firestore without it.
        raise # Re-raise to stop the script if Firebase initialization fails

db = firestore.client(app=app)
# Out:
# An error occurred: module 'importlib.metadata' has no attribute 'packages_distributions'
# Firebase Admin SDK initialized successfully.
# /usr/local/lib/python3.8/dist-packages/google/api_core/_python_version_support.py:237: FutureWarning: You are using a non-supported Python version (3.8.10). Google will not post any further updates to google.api_core supporting this Python version. Please upgrade to the latest Python version, or at least Python 3.10, and then update google.api_core.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ## setup spark

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, when, lit, to_timestamp, from_unixtime
from pyspark.sql.types import StructType, StructField, StringType, TimestampType, IntegerType, DoubleType
import time
import logging
# ---------- CONFIG ----------
KAFKA_BOOTSTRAP = "kafka:29092"                  

CHECKPOINT_BASE = "/data/checkpoints"

# Configure logger
logger = logging.getLogger("DataCleaning")
logger.setLevel(logging.INFO)
handler = logging.StreamHandler()
formatter = logging.Formatter("[%(asctime)s] %(levelname)s - %(message)s")
handler.setFormatter(formatter)
if not logger.hasHandlers():
    logger.addHandler(handler)
# ---------- Spark session ----------
spark = (
    SparkSession.builder
    .appName("health-streams-to-firebase")
    .getOrCreate()
)
spark.sparkContext.setLogLevel("ERROR")

# ---------- utils ----------
def read_topic(topic, schema):
    return (
        spark.readStream
             .format("kafka")
             .option("kafka.bootstrap.servers", KAFKA_BOOTSTRAP)
             .option("subscribe", topic)
             .option("startingOffsets", "latest")
             .load()
             .selectExpr("CAST(value AS STRING) as json_str")
             .select(from_json(col("json_str"), schema).alias("data"))   # <<< fixed
             .select("data.*")
    )


heart_rate_schema = StructType([
    StructField("user_id", StringType(), True),
    StructField("time", TimestampType(), True),
    StructField("heart_rate", IntegerType(), True)
])
steps_schema = StructType([
    StructField("user_id", StringType(), True),
    StructField("time", TimestampType(), True),
    StructField("steps", IntegerType(), True)
])
calories_schema = StructType([
    StructField("user_id", StringType(), True),
    StructField("time", TimestampType(), True),
    StructField("calories", DoubleType(), True)
])
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/10 10:41:53 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ## cleaning functions

# %%
from pyspark.sql.functions import from_json, col
from pyspark.sql.functions import current_timestamp

## ---------- timestamp normalization & cleaning ----------
def normalize_timestamp(df):
    candidates = [c for c in ["timestamp", "ts", "ts_ms", "time", "created_at"] if c in df.columns]
    logger.info(f"Normalizing timestamp — candidates: {candidates}")

    if not candidates:
        logger.warning("No timestamp found — creating current-time column.")
        return df.withColumn("timestamp", current_timestamp())

    src = candidates[0]
    logger.info(f"Using '{src}' as timestamp source.")
    src_col = col(src)

    # Only convert numeric timestamps; keep native timestamps unchanged
    df = df.withColumn(
        "timestamp",
        when(src_col.cast(DoubleType()).isNotNull(), 
             to_timestamp(from_unixtime(
                 (src_col.cast(DoubleType()) / when(src_col.cast(DoubleType()) > 1e12, lit(1000.0)).otherwise(lit(1.0))).cast("long")
             ))
        ).otherwise(src_col.cast(TimestampType()))
    )

    return df.drop(src)
def clean_heart_rate(df):
    logger.info("Cleaning heart rate stream...")
    df = df.withColumn("heart_rate", col("heart_rate").cast(IntegerType()))
    df = normalize_timestamp(df)
    df = df.dropna(subset=["heart_rate", "timestamp"])
    df = df.filter((col("heart_rate") > 0) & (col("heart_rate") < 300))
    logger.info("Heart rate cleaning complete (streaming mode).")
    return df


def clean_calories(df):
    logger.info("Cleaning calories stream...")
    df = df.withColumn("calories", col("calories").cast(DoubleType()))
    df = normalize_timestamp(df)
    df = df.dropna(subset=["calories", "timestamp"])
    df = df.filter(col("calories") >= 0)
    logger.info("Calories cleaning complete (streaming mode).")
    return df


def clean_steps(df):
    logger.info("Cleaning steps stream...")
    df = df.withColumn("steps", col("steps").cast(IntegerType()))
    df = normalize_timestamp(df)
    df = df.dropna(subset=["steps", "timestamp"])
    df = df.filter(col("steps") >= 0)
    logger.info("Steps cleaning complete (streaming mode).")
    return df
    

  
# ---------- prepare streams ----------

heart_rate_df = read_topic("heartrate", heart_rate_schema)
calories_df = read_topic("calories", calories_schema)
steps_df = read_topic("steps", steps_schema)

hr_clean = clean_heart_rate(heart_rate_df)
cal_clean = clean_calories(calories_df)
st_clean = clean_steps(steps_df)
# Out:
# [2025-11-10 10:41:56,839] INFO - Cleaning heart rate stream...
# [2025-11-10 10:41:56,876] INFO - Normalizing timestamp — candidates: ['time']
# [2025-11-10 10:41:56,877] INFO - Using 'time' as timestamp source.
# [2025-11-10 10:41:56,946] INFO - Heart rate cleaning complete (streaming mode).
# [2025-11-10 10:41:56,946] INFO - Cleaning calories stream...
# [2025-11-10 10:41:56,963] INFO - Normalizing timestamp — candidates: ['time']
# [2025-11-10 10:41:56,964] INFO - Using 'time' as timestamp source.
# [2025-11-10 10:41:57,029] INFO - Calories cleaning complete (streaming mode).
# [2025-11-10 10:41:57,030] INFO - Cleaning steps stream...
# [2025-11-10 10:41:57,052] INFO - Normalizing timestamp — candidates: ['time']
# [2025-11-10 10:41:57,053] INFO - Using 'time' as timestamp source.
# [2025-11-10 10:41:57,187] INFO - Steps cleaning complete (streaming mode).

# %% [markdown]
# ## anomaly detection functions

# %%
import time
from datetime import datetime

def send_alert_to_firestore(user_id, alert_type, value, firestore_client,timestamp):
    """
    Write an anomaly alert to Firestore.
    Each alert becomes a document in the 'alerts' collection.

    Args:
        user_id (str): The ID of the affected user.
        alert_type (str): Type of the alert, e.g., 'heart_rate', 'calories', etc.
        firestore_client: Initialized Firestore client (google.cloud.firestore.Client).
    """
    try:
        alerts_ref = firestore_client.collection("alerts")
        alert_doc = {
            "user_id": user_id,
            "type": alert_type,
            "value": value,
            "detected_at": timestamp,
            "alert_created_at_unix": int(time.time()),
            "status":"waiting"
        }

        alerts_ref.add(alert_doc)
        print(f"[ok] Alert written for user={user_id}: {alert_type} — {value}")

    except Exception as e:
        print(f"[error] Failed to write alert for user={user_id}: {e}")
        
def detect_heart_rate_anomalies(df, firestore_client):
    anomalies = df.filter((col("heart_rate") > 180) | (col("heart_rate") < 45))
    if anomalies.rdd.isEmpty():
        return
    for row in anomalies.toLocalIterator():
        send_alert_to_firestore(
            user_id=row.user_id,
            alert_type="heart_rate",
            value=row.heart_rate,
            firestore_client=firestore_client,
            timestamp= row.timestamp
        )
        
def detect_low_calories(df, firestore_client):
    low_activity = df.filter(col("calories") < 0.5)  # e.g. less than 0.5 kcal/min or similar
    if low_activity.rdd.isEmpty():
        return
    for row in low_activity.toLocalIterator():
        send_alert_to_firestore(
            user_id=row.user_id,
            alert_type="low_calories",
            value=row.calories,
            firestore_client=firestore_client,
            timestamp= row.timestamp
        )
        
def detect_inactivity(df, firestore_client):
    inactive = df.filter(col("steps") == 0)
    if inactive.rdd.isEmpty():
        return
    for row in inactive.toLocalIterator():
        send_alert_to_firestore(
            user_id=row.user_id,
            alert_type="inactivity",
            value=0,
            firestore_client=firestore_client,
            timestamp= row.timestamp
        )

# %% [markdown]
# ## write stream functions

# %%
import logging
import time
import datetime
import decimal
import json
from google.api_core.exceptions import GoogleAPICallError, RetryError

# logger (reuse your existing logger or this)
fs_logger = logging.getLogger("firestore-writer")
fs_logger.setLevel(logging.INFO)
if not fs_logger.hasHandlers():
    h = logging.StreamHandler()
    h.setFormatter(logging.Formatter("[%(levelname)s] %(asctime)s - %(message)s"))
    fs_logger.addHandler(h)


def _serialize_value(v):
    """Make values Firestore-safe: datetime -> ISO, Decimal -> float, fallback to str for non-JSON."""
    if v is None:
        return None
    if isinstance(v, (datetime.datetime, datetime.date)):
        return v.isoformat()
    if isinstance(v, decimal.Decimal):
        return float(v)
    # Bytes -> decode
    if isinstance(v, (bytes, bytearray)):
        try:
            return v.decode()
        except Exception:
            return str(v)
    # Test JSON-serializable quickly
    try:
        json.dumps(v)
        return v
    except Exception:
        return str(v)


def _commit_with_retries(batch_obj, max_retries=3, base_backoff=0.5):
    """Commit a Firestore batch with retries on transient errors."""
    attempt = 0
    while True:
        try:
            batch_obj.commit()
            return
        except (GoogleAPICallError, RetryError, IOError) as e:
            attempt += 1
            if attempt > max_retries:
                fs_logger.exception("Firestore commit failed after %d attempts", attempt - 1)
                raise
            backoff = base_backoff * (2 ** (attempt - 1))
            fs_logger.warning("Transient error committing firestore batch (attempt %d). Backing off %.2fs. Error: %s",
                              attempt, backoff, str(e))
            time.sleep(backoff)


def make_firestore_writer(collection_name, firestore_client, batch_size=500, max_retries=3):
    """
    Writes to Firestore under this structure:
      users/{user_id}/{collection_name}/{auto_doc_id}

    collection_name: e.g. "heart_rate", "calories", "steps"
    """
    def write_batch_to_firestore(batch_df, epoch_id):
        epoch_str = str(epoch_id) if epoch_id is not None else "(no-epoch)"
        try:
            rows = batch_df.count()
        except Exception as e:
            fs_logger.exception("[epoch %s] failed to count batch: %s", epoch_str, e)
            rows = None

        if not rows:
            fs_logger.info("[epoch %s] empty, skipping collection=%s", epoch_str, collection_name)
            return

        fs_logger.info("[epoch %s] writing %s rows to Firestore subcollections '%s'", epoch_str, rows, collection_name)

        docs_written = 0
        ops_in_current_batch = 0
        fs_batch = firestore_client.batch()

        try:
            for row in batch_df.toLocalIterator():
                data = row.asDict(recursive=True)
                user_id = data.get("user_id")

                if not user_id:
                    fs_logger.warning("[epoch %s] skipping row without user_id: %s", epoch_str, data)
                    continue

                # Serialize all values to Firestore-safe types
                for k, v in list(data.items()):
                    data[k] = _serialize_value(v)

                # Path: users/{user_id}/{collection_name}/{auto_doc_id}
                doc_ref = (
                    firestore_client.collection("users")
                    .document(str(user_id))
                    .collection(collection_name)
                    .document()
                )

                fs_batch.set(doc_ref, data)
                ops_in_current_batch += 1

                if ops_in_current_batch >= batch_size:
                    _commit_with_retries(fs_batch, max_retries=max_retries)
                    docs_written += ops_in_current_batch
                    ops_in_current_batch = 0
                    fs_batch = firestore_client.batch()

            if ops_in_current_batch > 0:
                _commit_with_retries(fs_batch, max_retries=max_retries)
                docs_written += ops_in_current_batch

            fs_logger.info("[epoch %s] wrote %d docs under users/*/%s/", epoch_str, docs_written, collection_name)

        except Exception as e:
            fs_logger.exception("[epoch %s] Firestore write failed: %s", epoch_str, e)
            raise

    return write_batch_to_firestore

# %% [markdown]
# ## cleaning stream queries

# %%
# start streams separately with their own checkpoints
# Pass the initialized Firestore client 'db' to your writer functions
hr_query = (
    hr_clean
    .writeStream
    .foreachBatch(make_firestore_writer("heart_rate", db)) # Pass the Firestore client here
    .option("checkpointLocation", f"{CHECKPOINT_BASE}/heart_rate")
    .outputMode("append")
    .start()
)

cal_query = (
    cal_clean
    .writeStream
    .foreachBatch(make_firestore_writer("calories", db)) # Pass the Firestore client here
    .option("checkpointLocation", f"{CHECKPOINT_BASE}/calories")
    .outputMode("append")
    .start()
)

st_query = (
    st_clean
    .writeStream
    .foreachBatch(make_firestore_writer("steps", db)) # Pass the Firestore client here
    .option("checkpointLocation", f"{CHECKPOINT_BASE}/steps")
    .outputMode("append")
    .start()
)
# Start streams for each detection type
hr_alerts = (
    hr_clean.writeStream
    .foreachBatch(lambda batch_df, epoch_id: detect_heart_rate_anomalies(batch_df, db))
    .option("checkpointLocation", f"{CHECKPOINT_BASE}/alerts_hr")
    .start()
)

cal_alerts = (
    cal_clean.writeStream
    .foreachBatch(lambda batch_df, epoch_id: detect_low_calories(batch_df, db))
    .option("checkpointLocation", f"{CHECKPOINT_BASE}/alerts_calories")
    .start()
)

st_alerts = (
    st_clean.writeStream
    .foreachBatch(lambda batch_df, epoch_id: detect_inactivity(batch_df, db))
    .option("checkpointLocation", f"{CHECKPOINT_BASE}/alerts_steps")
    .start()
)

spark.streams.awaitAnyTermination()


print("Started all streams. Waiting...")
spark.streams.awaitAnyTermination()
# Out:
# [INFO] 2025-11-10 10:42:06,414 - [epoch 239] writing 1 rows to Firestore subcollections 'calories'
# [INFO] 2025-11-10 10:42:06,414 - [epoch 239] writing 1 rows to Firestore subcollections 'steps'
# [INFO] 2025-11-10 10:42:06,415 - [epoch 13535] writing 12 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:07,880 - [epoch 13535] wrote 12 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:08,039 - [epoch 239] wrote 1 docs under users/*/steps/
# [INFO] 2025-11-10 10:42:08,041 - [epoch 239] wrote 1 docs under users/*/calories/
# [ok] Alert written for user=1503960366: inactivity — 0
# [INFO] 2025-11-10 10:42:08,523 - [epoch 13536] writing 5 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:09,312 - [epoch 13536] wrote 5 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:09,543 - [epoch 13537] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:09,764 - [epoch 13537] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:10,443 - [epoch 13538] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:10,705 - [epoch 13538] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:11,341 - [epoch 13539] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:11,695 - [epoch 13539] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:12,321 - [epoch 13540] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:12,739 - [epoch 13540] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:13,351 - [epoch 13541] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:13,705 - [epoch 13541] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:14,327 - [epoch 13542] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:14,697 - [epoch 13542] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:15,314 - [epoch 13543] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:15,716 - [epoch 13543] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:16,337 - [epoch 13544] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:16,691 - [epoch 13544] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:17,308 - [epoch 13545] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:17,739 - [epoch 13545] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:18,342 - [epoch 13546] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:18,748 - [epoch 13546] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:19,348 - [epoch 13547] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:19,730 - [epoch 13547] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:20,327 - [epoch 13548] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:20,721 - [epoch 13548] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:21,314 - [epoch 13549] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:21,714 - [epoch 13549] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:22,317 - [epoch 13550] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:22,758 - [epoch 13550] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:23,361 - [epoch 13551] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:23,747 - [epoch 13551] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:24,348 - [epoch 13552] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:24,771 - [epoch 13552] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:25,395 - [epoch 13553] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:25,771 - [epoch 13553] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:26,425 - [epoch 13554] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:26,825 - [epoch 13554] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:27,422 - [epoch 13555] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:27,772 - [epoch 13555] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:28,365 - [epoch 13556] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:28,831 - [epoch 13556] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:29,420 - [epoch 13557] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:29,789 - [epoch 13557] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:30,387 - [epoch 13558] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:30,793 - [epoch 13558] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:31,386 - [epoch 13559] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:31,808 - [epoch 13559] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:32,406 - [epoch 13560] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:32,813 - [epoch 13560] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:33,398 - [epoch 13561] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:33,922 - [epoch 13561] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:34,520 - [epoch 13562] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:34,855 - [epoch 13562] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:35,445 - [epoch 13563] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:35,856 - [epoch 13563] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:36,442 - [epoch 13564] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:36,949 - [epoch 13564] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:37,547 - [epoch 13565] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:37,872 - [epoch 13565] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:38,466 - [epoch 13566] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:38,954 - [epoch 13566] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:39,580 - [epoch 13567] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:39,843 - [epoch 13567] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:40,454 - [epoch 13568] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:40,929 - [epoch 13568] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:41,541 - [epoch 13569] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:41,856 - [epoch 13569] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:42,520 - [epoch 13570] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:42,852 - [epoch 13570] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:43,457 - [epoch 13571] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:43,881 - [epoch 13571] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:44,472 - [epoch 13572] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:44,857 - [epoch 13572] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:45,445 - [epoch 13573] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:45,855 - [epoch 13573] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:46,453 - [epoch 13574] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:46,868 - [epoch 13574] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:47,464 - [epoch 13575] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:47,871 - [epoch 13575] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:48,469 - [epoch 13576] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:48,869 - [epoch 13576] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:49,470 - [epoch 13577] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:49,872 - [epoch 13577] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:50,482 - [epoch 13578] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:50,872 - [epoch 13578] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:51,473 - [epoch 13579] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:51,896 - [epoch 13579] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:52,498 - [epoch 13580] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:52,967 - [epoch 13580] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:53,565 - [epoch 13581] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:53,956 - [epoch 13581] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:54,551 - [epoch 13582] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:54,923 - [epoch 13582] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:55,519 - [epoch 13583] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:55,927 - [epoch 13583] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:56,527 - [epoch 13584] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:56,914 - [epoch 13584] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:57,512 - [epoch 13585] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:57,952 - [epoch 13585] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:58,623 - [epoch 13586] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:58,966 - [epoch 13586] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:42:59,570 - [epoch 13587] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:42:59,954 - [epoch 13587] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:00,586 - [epoch 13588] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:00,737 - [epoch 240] writing 1 rows to Firestore subcollections 'steps'
# [INFO] 2025-11-10 10:43:00,772 - [epoch 240] writing 1 rows to Firestore subcollections 'calories'
# [INFO] 2025-11-10 10:43:00,961 - [epoch 13588] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:01,437 - [epoch 240] wrote 1 docs under users/*/steps/
# [INFO] 2025-11-10 10:43:01,446 - [epoch 240] wrote 1 docs under users/*/calories/
# [INFO] 2025-11-10 10:43:01,556 - [epoch 13589] writing 1 rows to Firestore subcollections 'heart_rate'
# [ok] Alert written for user=8378563200: inactivity — 0
# [INFO] 2025-11-10 10:43:01,955 - [epoch 13589] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:02,578 - [epoch 13590] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:02,964 - [epoch 13590] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:03,570 - [epoch 13591] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:03,983 - [epoch 13591] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:04,588 - [epoch 13592] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:05,004 - [epoch 13592] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:05,604 - [epoch 13593] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:05,975 - [epoch 13593] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:06,606 - [epoch 13594] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:07,005 - [epoch 13594] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:07,606 - [epoch 13595] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:07,989 - [epoch 13595] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:08,588 - [epoch 13596] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:09,013 - [epoch 13596] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:09,609 - [epoch 13597] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:09,992 - [epoch 13597] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:10,590 - [epoch 13598] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:11,059 - [epoch 13598] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:11,654 - [epoch 13599] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:12,100 - [epoch 13599] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:12,705 - [epoch 13600] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:13,026 - [epoch 13600] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:13,623 - [epoch 13601] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:14,046 - [epoch 13601] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:14,676 - [epoch 13602] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:15,084 - [epoch 13602] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:15,760 - [epoch 13603] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:16,277 - [epoch 13603] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:16,910 - [epoch 13604] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:17,096 - [epoch 13604] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:17,728 - [epoch 13605] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:18,131 - [epoch 13605] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:18,735 - [epoch 13606] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:19,256 - [epoch 13606] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:19,848 - [epoch 13607] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:20,115 - [epoch 13607] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:20,708 - [epoch 13608] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:21,127 - [epoch 13608] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:21,751 - [epoch 13609] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:22,120 - [epoch 13609] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:22,762 - [epoch 13610] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:23,148 - [epoch 13610] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:23,761 - [epoch 13611] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:24,170 - [epoch 13611] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:24,777 - [epoch 13612] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:25,154 - [epoch 13612] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:25,759 - [epoch 13613] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:26,143 - [epoch 13613] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:26,746 - [epoch 13614] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:27,140 - [epoch 13614] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:27,785 - [epoch 13615] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:28,187 - [epoch 13615] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:28,790 - [epoch 13616] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:29,181 - [epoch 13616] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:29,788 - [epoch 13617] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:30,190 - [epoch 13617] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:30,792 - [epoch 13618] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:31,256 - [epoch 13618] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:31,878 - [epoch 13619] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:32,203 - [epoch 13619] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:32,853 - [epoch 13620] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:33,213 - [epoch 13620] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:33,838 - [epoch 13621] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:34,211 - [epoch 13621] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:34,841 - [epoch 13622] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:35,230 - [epoch 13622] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:35,844 - [epoch 13623] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:36,248 - [epoch 13623] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:36,848 - [epoch 13624] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:37,271 - [epoch 13624] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:37,865 - [epoch 13625] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:38,234 - [epoch 13625] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:38,834 - [epoch 13626] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:39,238 - [epoch 13626] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:39,861 - [epoch 13627] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:40,252 - [epoch 13627] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:40,885 - [epoch 13628] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:41,256 - [epoch 13628] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:41,904 - [epoch 13629] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:42,265 - [epoch 13629] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:42,905 - [epoch 13630] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:43,287 - [epoch 13630] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:43,924 - [epoch 13631] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:44,283 - [epoch 13631] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:44,936 - [epoch 13632] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:45,291 - [epoch 13632] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:45,932 - [epoch 13633] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:46,331 - [epoch 13633] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:46,963 - [epoch 13634] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:47,303 - [epoch 13634] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:47,923 - [epoch 13635] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:48,317 - [epoch 13635] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:48,939 - [epoch 13636] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:49,351 - [epoch 13636] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:49,949 - [epoch 13637] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:50,354 - [epoch 13637] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:50,943 - [epoch 13638] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:51,357 - [epoch 13638] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:51,946 - [epoch 13639] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:52,316 - [epoch 13639] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:52,921 - [epoch 13640] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:53,332 - [epoch 13640] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:53,920 - [epoch 13641] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:54,338 - [epoch 13641] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:54,925 - [epoch 13642] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:55,379 - [epoch 13642] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:55,974 - [epoch 13643] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:56,356 - [epoch 13643] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:56,948 - [epoch 13644] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:57,357 - [epoch 13644] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:57,956 - [epoch 13645] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:58,363 - [epoch 13645] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:58,951 - [epoch 13646] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:43:59,380 - [epoch 13646] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:43:59,970 - [epoch 13647] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:00,392 - [epoch 13647] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:00,613 - [epoch 241] writing 1 rows to Firestore subcollections 'steps'
# [INFO] 2025-11-10 10:44:00,617 - [epoch 241] writing 1 rows to Firestore subcollections 'calories'
# [INFO] 2025-11-10 10:44:00,982 - [epoch 13648] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:01,297 - [epoch 241] wrote 1 docs under users/*/steps/
# [INFO] 2025-11-10 10:44:01,333 - [epoch 241] wrote 1 docs under users/*/calories/
# [INFO] 2025-11-10 10:44:01,406 - [epoch 13648] wrote 1 docs under users/*/heart_rate/
# [ok] Alert written for user=1644430081: inactivity — 0
# [INFO] 2025-11-10 10:44:02,002 - [epoch 13649] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:02,393 - [epoch 13649] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:03,018 - [epoch 13650] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:03,372 - [epoch 13650] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:04,016 - [epoch 13651] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:04,446 - [epoch 13651] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:05,061 - [epoch 13652] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:05,432 - [epoch 13652] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:06,046 - [epoch 13653] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:06,431 - [epoch 13653] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:07,054 - [epoch 13654] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:07,448 - [epoch 13654] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:08,050 - [epoch 13655] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:08,469 - [epoch 13655] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:09,069 - [epoch 13656] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:09,449 - [epoch 13656] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:10,057 - [epoch 13657] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:10,507 - [epoch 13657] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:11,124 - [epoch 13658] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:11,483 - [epoch 13658] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:12,076 - [epoch 13659] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:12,463 - [epoch 13659] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:13,068 - [epoch 13660] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:13,465 - [epoch 13660] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:14,103 - [epoch 13661] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:14,460 - [epoch 13661] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:15,101 - [epoch 13662] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:15,463 - [epoch 13662] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:16,072 - [epoch 13663] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:16,465 - [epoch 13663] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:17,088 - [epoch 13664] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:17,483 - [epoch 13664] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:18,072 - [epoch 13665] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:18,489 - [epoch 13665] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:19,093 - [epoch 13666] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:19,501 - [epoch 13666] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:20,093 - [epoch 13667] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:20,554 - [epoch 13667] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:21,143 - [epoch 13668] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:21,556 - [epoch 13668] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:22,222 - [epoch 13669] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:22,518 - [epoch 13669] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:23,148 - [epoch 13670] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:23,518 - [epoch 13670] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:24,129 - [epoch 13671] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:24,590 - [epoch 13671] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:25,205 - [epoch 13672] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:25,538 - [epoch 13672] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:26,194 - [epoch 13673] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:26,561 - [epoch 13673] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:27,159 - [epoch 13674] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:27,556 - [epoch 13674] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:28,143 - [epoch 13675] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:28,574 - [epoch 13675] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:29,174 - [epoch 13676] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:29,566 - [epoch 13676] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:30,179 - [epoch 13677] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:30,571 - [epoch 13677] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:31,172 - [epoch 13678] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:31,583 - [epoch 13678] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:32,179 - [epoch 13679] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:32,597 - [epoch 13679] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:33,191 - [epoch 13680] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:33,656 - [epoch 13680] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:34,258 - [epoch 13681] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:34,607 - [epoch 13681] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:35,197 - [epoch 13682] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:35,629 - [epoch 13682] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:36,219 - [epoch 13683] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:36,613 - [epoch 13683] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:37,206 - [epoch 13684] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:37,613 - [epoch 13684] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:38,203 - [epoch 13685] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:38,639 - [epoch 13685] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:39,262 - [epoch 13686] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:39,673 - [epoch 13686] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:40,263 - [epoch 13687] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:40,630 - [epoch 13687] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:41,223 - [epoch 13688] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:41,655 - [epoch 13688] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:42,248 - [epoch 13689] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:42,645 - [epoch 13689] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:43,236 - [epoch 13690] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:43,641 - [epoch 13690] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:44,227 - [epoch 13691] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:44,656 - [epoch 13691] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:45,254 - [epoch 13692] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:45,671 - [epoch 13692] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:46,268 - [epoch 13693] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:46,677 - [epoch 13693] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:47,263 - [epoch 13694] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:47,678 - [epoch 13694] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:48,264 - [epoch 13695] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:48,707 - [epoch 13695] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:49,307 - [epoch 13696] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:49,692 - [epoch 13696] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:50,279 - [epoch 13697] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:50,699 - [epoch 13697] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:51,287 - [epoch 13698] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:51,698 - [epoch 13698] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:52,283 - [epoch 13699] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:52,758 - [epoch 13699] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:53,356 - [epoch 13700] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:53,719 - [epoch 13700] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:54,312 - [epoch 13701] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:54,889 - [epoch 13701] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:55,491 - [epoch 13702] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:55,734 - [epoch 13702] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:56,337 - [epoch 13703] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:56,733 - [epoch 13703] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:57,337 - [epoch 13704] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:57,769 - [epoch 13704] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:58,356 - [epoch 13705] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:58,759 - [epoch 13705] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:44:59,352 - [epoch 13706] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:44:59,802 - [epoch 13706] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:00,389 - [epoch 13707] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:00,684 - [epoch 242] writing 1 rows to Firestore subcollections 'calories'
# [INFO] 2025-11-10 10:45:00,712 - [epoch 242] writing 1 rows to Firestore subcollections 'steps'
# [INFO] 2025-11-10 10:45:00,776 - [epoch 13707] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:01,362 - [epoch 13708] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:01,372 - [epoch 242] wrote 1 docs under users/*/calories/
# [INFO] 2025-11-10 10:45:01,381 - [epoch 242] wrote 1 docs under users/*/steps/
# [ok] Alert written for user=1844505072: inactivity — 0
# [INFO] 2025-11-10 10:45:01,782 - [epoch 13708] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:02,373 - [epoch 13709] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:02,778 - [epoch 13709] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:03,367 - [epoch 13710] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:03,777 - [epoch 13710] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:04,383 - [epoch 13711] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:04,780 - [epoch 13711] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:05,405 - [epoch 13712] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:05,807 - [epoch 13712] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:06,394 - [epoch 13713] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:06,837 - [epoch 13713] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:07,420 - [epoch 13714] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:07,802 - [epoch 13714] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:08,393 - [epoch 13715] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:08,829 - [epoch 13715] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:09,419 - [epoch 13716] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:09,837 - [epoch 13716] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:10,402 - [epoch 13717] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:10,865 - [epoch 13717] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:11,433 - [epoch 13718] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:11,819 - [epoch 13718] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:12,411 - [epoch 13719] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:12,826 - [epoch 13719] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:13,399 - [epoch 13720] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:13,839 - [epoch 13720] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:14,407 - [epoch 13721] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:14,855 - [epoch 13721] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:15,418 - [epoch 13722] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:15,868 - [epoch 13722] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:16,430 - [epoch 13723] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:16,863 - [epoch 13723] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:17,424 - [epoch 13724] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:17,856 - [epoch 13724] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:18,428 - [epoch 13725] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:18,856 - [epoch 13725] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:19,425 - [epoch 13726] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:19,864 - [epoch 13726] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:20,429 - [epoch 13727] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:20,900 - [epoch 13727] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:21,481 - [epoch 13728] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:21,892 - [epoch 13728] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:22,466 - [epoch 13729] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:22,892 - [epoch 13729] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:23,480 - [epoch 13730] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:23,954 - [epoch 13730] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:24,532 - [epoch 13731] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:24,939 - [epoch 13731] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:25,517 - [epoch 13732] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:25,895 - [epoch 13732] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:26,487 - [epoch 13733] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:26,916 - [epoch 13733] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:27,522 - [epoch 13734] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:27,896 - [epoch 13734] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:28,472 - [epoch 13735] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:29,040 - [epoch 13735] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:29,602 - [epoch 13736] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:29,956 - [epoch 13736] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:30,558 - [epoch 13737] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:30,914 - [epoch 13737] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:31,505 - [epoch 13738] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:31,925 - [epoch 13738] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:32,490 - [epoch 13739] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:32,915 - [epoch 13739] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:33,478 - [epoch 13740] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:33,928 - [epoch 13740] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:34,522 - [epoch 13741] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:34,988 - [epoch 13741] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:35,553 - [epoch 13742] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:35,956 - [epoch 13742] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:36,526 - [epoch 13743] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:36,966 - [epoch 13743] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:37,540 - [epoch 13744] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:37,933 - [epoch 13744] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:38,497 - [epoch 13745] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:39,276 - [epoch 13745] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:39,822 - [epoch 13746] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:40,501 - [epoch 13746] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:40,825 - [epoch 13747] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:40,980 - [epoch 13747] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:41,543 - [epoch 13748] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:41,968 - [epoch 13748] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:42,531 - [epoch 13749] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:42,980 - [epoch 13749] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:43,549 - [epoch 13750] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:43,983 - [epoch 13750] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:44,679 - [epoch 13751] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:45,091 - [epoch 13751] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:45,721 - [epoch 13752] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:46,074 - [epoch 13752] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:46,702 - [epoch 13753] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:47,087 - [epoch 13753] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:47,677 - [epoch 13754] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:48,130 - [epoch 13754] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:48,722 - [epoch 13755] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:49,091 - [epoch 13755] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:49,716 - [epoch 13756] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:50,094 - [epoch 13756] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:50,688 - [epoch 13757] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:51,115 - [epoch 13757] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:51,711 - [epoch 13758] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:52,115 - [epoch 13758] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:52,701 - [epoch 13759] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:53,136 - [epoch 13759] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:53,699 - [epoch 13760] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:54,179 - [epoch 13760] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:54,754 - [epoch 13761] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:55,156 - [epoch 13761] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:55,734 - [epoch 13762] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:56,127 - [epoch 13762] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:56,692 - [epoch 13763] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:57,140 - [epoch 13763] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:57,723 - [epoch 13764] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:58,136 - [epoch 13764] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:58,701 - [epoch 13765] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:45:59,137 - [epoch 13765] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:45:59,711 - [epoch 13766] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:46:00,188 - [epoch 13766] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:46:00,596 - [epoch 243] writing 1 rows to Firestore subcollections 'calories'
# [INFO] 2025-11-10 10:46:00,607 - [epoch 243] writing 1 rows to Firestore subcollections 'steps'
# [INFO] 2025-11-10 10:46:00,750 - [epoch 13767] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:46:01,185 - [epoch 13767] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:46:01,261 - [epoch 243] wrote 1 docs under users/*/calories/
# [INFO] 2025-11-10 10:46:01,261 - [epoch 243] wrote 1 docs under users/*/steps/
# [ok] Alert written for user=1927972279: inactivity — 0
# [INFO] 2025-11-10 10:46:01,753 - [epoch 13768] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:46:02,183 - [epoch 13768] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:46:02,755 - [epoch 13769] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:46:03,180 - [epoch 13769] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:46:03,762 - [epoch 13770] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:46:04,180 - [epoch 13770] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:46:04,745 - [epoch 13771] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:46:05,181 - [epoch 13771] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:46:05,748 - [epoch 13772] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:46:06,188 - [epoch 13772] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:46:06,753 - [epoch 13773] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:46:07,253 - [epoch 13773] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:46:07,843 - [epoch 13774] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:46:08,198 - [epoch 13774] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:46:08,760 - [epoch 13775] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:46:09,195 - [epoch 13775] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:46:09,757 - [epoch 13776] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:46:10,206 - [epoch 13776] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 10:46:10,769 - [epoch 13777] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 10:46:11,210 - [epoch 13777] wrote 1 docs under users/*/heart_rate/
# ...
# [INFO] 2025-11-10 11:10:29,264 - [epoch 15222] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:29,832 - [epoch 15223] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:30,269 - [epoch 15223] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:30,826 - [epoch 15224] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:31,283 - [epoch 15224] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:31,843 - [epoch 15225] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:32,289 - [epoch 15225] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:32,842 - [epoch 15226] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:33,282 - [epoch 15226] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:33,845 - [epoch 15227] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:34,289 - [epoch 15227] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:34,848 - [epoch 15228] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:35,287 - [epoch 15228] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:35,844 - [epoch 15229] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:36,359 - [epoch 15229] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:36,915 - [epoch 15230] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:37,280 - [epoch 15230] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:37,834 - [epoch 15231] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:38,319 - [epoch 15231] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:38,872 - [epoch 15232] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:39,302 - [epoch 15232] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:39,862 - [epoch 15233] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:40,318 - [epoch 15233] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:40,890 - [epoch 15234] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:41,306 - [epoch 15234] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:41,860 - [epoch 15235] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:42,371 - [epoch 15235] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:42,930 - [epoch 15236] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:43,303 - [epoch 15236] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:43,860 - [epoch 15237] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:44,369 - [epoch 15237] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:44,923 - [epoch 15238] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:45,372 - [epoch 15238] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:45,926 - [epoch 15239] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:46,374 - [epoch 15239] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:46,930 - [epoch 15240] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:47,372 - [epoch 15240] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:47,929 - [epoch 15241] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:48,370 - [epoch 15241] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:48,925 - [epoch 15242] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:49,392 - [epoch 15242] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:49,945 - [epoch 15243] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:50,379 - [epoch 15243] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:50,934 - [epoch 15244] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:51,372 - [epoch 15244] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:51,928 - [epoch 15245] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:52,359 - [epoch 15245] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:52,913 - [epoch 15246] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:53,363 - [epoch 15246] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:53,919 - [epoch 15247] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:54,371 - [epoch 15247] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:54,927 - [epoch 15248] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:55,370 - [epoch 15248] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:55,930 - [epoch 15249] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:56,437 - [epoch 15249] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:57,041 - [epoch 15250] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:57,406 - [epoch 15250] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:57,967 - [epoch 15251] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:58,395 - [epoch 15251] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:58,976 - [epoch 15252] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:10:59,388 - [epoch 15252] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:10:59,948 - [epoch 15253] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:00,402 - [epoch 15253] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:00,610 - [epoch 268] writing 1 rows to Firestore subcollections 'calories'
# [INFO] 2025-11-10 11:11:00,613 - [epoch 268] writing 1 rows to Firestore subcollections 'steps'
# [INFO] 2025-11-10 11:11:00,997 - [epoch 15254] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:01,281 - [epoch 268] wrote 1 docs under users/*/calories/
# [INFO] 2025-11-10 11:11:01,281 - [epoch 268] wrote 1 docs under users/*/steps/
# [INFO] 2025-11-10 11:11:01,394 - [epoch 15254] wrote 1 docs under users/*/heart_rate/
# [ok] Alert written for user=5577150313: inactivity — 0
# [INFO] 2025-11-10 11:11:01,953 - [epoch 15255] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:02,402 - [epoch 15255] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:02,962 - [epoch 15256] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:03,422 - [epoch 15256] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:03,998 - [epoch 15257] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:04,446 - [epoch 15257] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:05,018 - [epoch 15258] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:05,421 - [epoch 15258] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:05,981 - [epoch 15259] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:06,531 - [epoch 15259] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:07,088 - [epoch 15260] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:07,443 - [epoch 15260] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:08,001 - [epoch 15261] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:08,447 - [epoch 15261] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:09,011 - [epoch 15262] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:09,446 - [epoch 15262] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:10,009 - [epoch 15263] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:10,458 - [epoch 15263] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:11,015 - [epoch 15264] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:11,463 - [epoch 15264] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:12,019 - [epoch 15265] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:12,470 - [epoch 15265] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:13,052 - [epoch 15266] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:13,471 - [epoch 15266] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:14,033 - [epoch 15267] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:14,470 - [epoch 15267] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:15,026 - [epoch 15268] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:15,477 - [epoch 15268] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:16,032 - [epoch 15269] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:16,473 - [epoch 15269] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:17,037 - [epoch 15270] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:17,493 - [epoch 15270] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:18,051 - [epoch 15271] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:18,479 - [epoch 15271] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:19,041 - [epoch 15272] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:19,511 - [epoch 15272] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:20,070 - [epoch 15273] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:20,511 - [epoch 15273] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:21,066 - [epoch 15274] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:21,487 - [epoch 15274] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:22,046 - [epoch 15275] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:22,502 - [epoch 15275] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:23,055 - [epoch 15276] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:23,524 - [epoch 15276] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:24,117 - [epoch 15277] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:24,547 - [epoch 15277] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:25,139 - [epoch 15278] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:25,563 - [epoch 15278] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:26,150 - [epoch 15279] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:26,570 - [epoch 15279] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:27,192 - [epoch 15280] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:27,619 - [epoch 15280] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:28,192 - [epoch 15281] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:28,625 - [epoch 15281] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:29,231 - [epoch 15282] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:29,607 - [epoch 15282] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:30,247 - [epoch 15283] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:30,657 - [epoch 15283] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:31,245 - [epoch 15284] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:31,647 - [epoch 15284] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:32,201 - [epoch 15285] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:32,733 - [epoch 15285] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:33,289 - [epoch 15286] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:33,655 - [epoch 15286] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:34,219 - [epoch 15287] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:34,667 - [epoch 15287] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:35,221 - [epoch 15288] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:35,692 - [epoch 15288] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:36,245 - [epoch 15289] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:36,689 - [epoch 15289] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:37,245 - [epoch 15290] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:37,691 - [epoch 15290] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:38,249 - [epoch 15291] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:38,677 - [epoch 15291] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:39,233 - [epoch 15292] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:39,678 - [epoch 15292] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:40,233 - [epoch 15293] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:40,704 - [epoch 15293] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:41,266 - [epoch 15294] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:41,703 - [epoch 15294] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:42,260 - [epoch 15295] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:42,723 - [epoch 15295] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:43,290 - [epoch 15296] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:43,713 - [epoch 15296] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:44,268 - [epoch 15297] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:44,769 - [epoch 15297] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:45,328 - [epoch 15298] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:45,711 - [epoch 15298] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:46,284 - [epoch 15299] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:46,724 - [epoch 15299] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:47,279 - [epoch 15300] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:47,731 - [epoch 15300] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:48,292 - [epoch 15301] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:48,746 - [epoch 15301] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:49,303 - [epoch 15302] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:49,733 - [epoch 15302] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:50,325 - [epoch 15303] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:50,729 - [epoch 15303] wrote 1 docs under users/*/heart_rate/
# [INFO] 2025-11-10 11:11:51,283 - [epoch 15304] writing 1 rows to Firestore subcollections 'heart_rate'
# [INFO] 2025-11-10 11:11:51,949 - [epoch 15304] wrote 1 docs under users/*/heart_rate/

# %%
for q in spark.streams.active:
    q.stop()
print("✅ Stopped all active queries.")
